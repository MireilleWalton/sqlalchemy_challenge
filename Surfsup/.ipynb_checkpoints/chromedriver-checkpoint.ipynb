# %%
from splinter import Browser
from bs4 import BeautifulSoup

# %%
browser = Browser('chrome')
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 browser = Browser('chrome')
#
# File ~/anaconda3/envs/Bootcamp/lib/python3.10/site-packages/splinter/browser.py:125, in Browser(driver_name, retry_count, *args, **kwargs)
#     122 if driver is None:
#     123     raise DriverNotFoundError(f'Driver for {driver_name} was not found.')
# --> 125 return get_driver(driver, retry_count=retry_count, *args, **kwargs)
#
# File ~/anaconda3/envs/Bootcamp/lib/python3.10/site-packages/splinter/browser.py:97, in get_driver(driver, retry_count, *args, **kwargs)
#      94     except driver_exceptions as e:
#      95         err = e
# ---> 97 raise err
#
# File ~/anaconda3/envs/Bootcamp/lib/python3.10/site-packages/splinter/browser.py:93, in get_driver(driver, retry_count, *args, **kwargs)
#      91 for _ in range(retry_count):
#      92     try:
# ---> 93         return driver(*args, **kwargs)
#      94     except driver_exceptions as e:
#      95         err = e
#
# File ~/anaconda3/envs/Bootcamp/lib/python3.10/site-packages/splinter/driver/webdriver/chrome.py:42, in WebDriver.__init__(self, options, user_agent, wait_time, fullscreen, incognito, headless, **kwargs)
#      39     options.add_argument("--headless")
#      40     options.add_argument("--disable-gpu")
# ---> 42 driver = Chrome(options=options, **kwargs)
#      44 super(WebDriver, self).__init__(driver, wait_time)
#
# File ~/anaconda3/envs/Bootcamp/lib/python3.10/site-packages/selenium/webdriver/chrome/webdriver.py:70, in WebDriver.__init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, service, keep_alive)
#      67 if not service:
#      68     service = Service(executable_path, port, service_args, service_log_path)
# ---> 70 super(WebDriver, self).__init__(DesiredCapabilities.CHROME['browserName'], "goog",
#      71                                 port, options,
#      72                                 service_args, desired_capabilities,
#      73                                 service_log_path, service, keep_alive)
#
# File ~/anaconda3/envs/Bootcamp/lib/python3.10/site-packages/selenium/webdriver/chromium/webdriver.py:92, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, port, options, service_args, desired_capabilities, service_log_path, service, keep_alive)
#      89 self.service.start()
#      91 try:
# ---> 92     RemoteWebDriver.__init__(
#      93         self,
#      94         command_executor=ChromiumRemoteConnection(
#      95             remote_server_addr=self.service.service_url,
#      96             browser_name=browser_name, vendor_prefix=vendor_prefix,
#      97             keep_alive=keep_alive, ignore_proxy=_ignore_proxy),
#      98         options=options)
#      99 except Exception:
#     100     self.quit()
#
# File ~/anaconda3/envs/Bootcamp/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:275, in WebDriver.__init__(self, command_executor, desired_capabilities, browser_profile, proxy, keep_alive, file_detector, options)
#     273 self._authenticator_id = None
#     274 self.start_client()
# --> 275 self.start_session(capabilities, browser_profile)
#
# File ~/anaconda3/envs/Bootcamp/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:365, in WebDriver.start_session(self, capabilities, browser_profile)
#     363 w3c_caps = _make_w3c_caps(capabilities)
#     364 parameters = {"capabilities": w3c_caps}
# --> 365 response = self.execute(Command.NEW_SESSION, parameters)
#     366 if 'sessionId' not in response:
#     367     response = response['value']
#
# File ~/anaconda3/envs/Bootcamp/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:430, in WebDriver.execute(self, driver_command, params)
#     428 response = self.command_executor.execute(driver_command, params)
#     429 if response:
# --> 430     self.error_handler.check_response(response)
#     431     response['value'] = self._unwrap_value(
#     432         response.get('value', None))
#     433     return response
#
# File ~/anaconda3/envs/Bootcamp/lib/python3.10/site-packages/selenium/webdriver/remote/errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     245         alert_text = value['alert'].get('text')
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# WebDriverException: Message: unknown error: cannot find Chrome binary
# Stacktrace:
# 0   chromedriver                        0x0000000100988a58 chromedriver + 4991576
# 1   chromedriver                        0x000000010097ffa3 chromedriver + 4956067
# 2   chromedriver                        0x0000000100532607 chromedriver + 443911
# 3   chromedriver                        0x00000001005604b7 chromedriver + 631991
# 4   chromedriver                        0x000000010055f64c chromedriver + 628300
# 5   chromedriver                        0x00000001005a824c chromedriver + 926284
# 6   chromedriver                        0x00000001005a75af chromedriver + 923055
# 7   chromedriver                        0x000000010059e633 chromedriver + 886323
# 8   chromedriver                        0x000000010056a6f9 chromedriver + 673529
# 9   chromedriver                        0x000000010056b8de chromedriver + 678110
# 10  chromedriver                        0x00000001009448a9 chromedriver + 4712617
# 11  chromedriver                        0x00000001009498b4 chromedriver + 4733108
# 12  chromedriver                        0x0000000100950799 chromedriver + 4761497
# 13  chromedriver                        0x000000010094a60a chromedriver + 4736522
# 14  chromedriver                        0x000000010091d87c chromedriver + 4552828
# 15  chromedriver                        0x0000000100968c08 chromedriver + 4860936
# 16  chromedriver                        0x0000000100968d87 chromedriver + 4861319
# 17  chromedriver                        0x0000000100978edf chromedriver + 4927199
# 18  libsystem_pthread.dylib             0x00007ff80f5f81d3 _pthread_start + 125
# 19  libsystem_pthread.dylib             0x00007ff80f5f3bd3 thread_start + 15

# %% [raw]
# url = 'http://quotes.toscrape.com/'
# browser.visit(url)
